# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import plotly.express as px

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a7c8c292-4e45-4d11-84e7-3c3507df4e6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a7c8c292-4e45-4d11-84e7-3c3507df4e6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('netflix_titles.csv')

# %%
data.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
# Drop Columns
data.drop(columns=['show_id', 'cast', 'director', 'description'], inplace=True)

# Replacments
data['country'] = data['country'].fillna(data['country'].mode()[0])

# Drop the rest
data.dropna(inplace=True)

# %% [markdown]
# Added Date

# %%
# Change Data Type to DateTime
data['date_added'] = pd.to_datetime(data['date_added'].str.strip(), format='mixed', errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7b78b0635938> in <cell line: 0>()
# ----> 1 data['date_added'] = pd.to_datetime(data['date_added'].str.strip(), format='mixed', errors='coerce')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Country Column

# %%
# เก็บไว้เฉพาะประเทศแรกจากแต่ละรายการเท่านั้น
data['principal_country'] = data['country'].apply(lambda x: x.split(",")[0])

# %% [markdown]
# Rating Ages

# %%
ratings_ages = {
    'TV-PG': 'Older Kids',
    'TV-MA': 'Adults',
    'TV-Y7-FV': 'Older Kids',
    'TV-Y7': 'Older Kids',
    'TV-14': 'Teens',
    'R': 'Adults',
    'TV-Y': 'Kids',
    'NR': 'Adults',
    'PG-13': 'Teens',
    'TV-G': 'Kids',
    'PG': 'Older Kids',
    'G': 'Kids',
    'UR': 'Adults',
    'NC-17': 'Adults'
}

# เปลี่ยนค่าการจัดเรตเป็นกลุ่มอายุที่สอดคล้องกับเรตนั้น
data['ages'] = data['rating'].replace(ratings_ages)
data['ages'].unique()
# Out:
# array(['Teens', 'Adults', 'Older Kids', 'Kids'], dtype=object)

# %%
data.head()
# Out:
#       type                  title        country date_added  release_year  \
# 0    Movie   Dick Johnson Is Dead  United States 2021-09-25          2020
# 1  TV Show          Blood & Water   South Africa 2021-09-24          2021
# 2  TV Show              Ganglands  United States 2021-09-24          2021
# 3  TV Show  Jailbirds New Orleans  United States 2021-09-24          2021
# 4  TV Show           Kota Factory          India 2021-09-24          2021
#
#   rating   duration                                          listed_in  \
# 0  PG-13     90 min                                      Documentaries
# 1  TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2  TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3  TV-MA   1 Season                             Docuseries, Reality TV
# 4  TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
#
#   principal_country    ages
# 0     United States   Teens
# 1      South Africa  Adults
# ...

# %%
data.to_csv('netflix_titles_clean.csv', index=False)

# %%
from google.colab import files
files.download('netflix_titles_clean.csv')

# %%
df = pd.read_csv('netflix_titles_clean.csv')

# %%
df.head()
# Out:
#       type                  title        country  date_added  release_year  \
# 0    Movie   Dick Johnson Is Dead  United States  2021-09-25          2020
# 1  TV Show          Blood & Water   South Africa  2021-09-24          2021
# 2  TV Show              Ganglands  United States  2021-09-24          2021
# 3  TV Show  Jailbirds New Orleans  United States  2021-09-24          2021
# 4  TV Show           Kota Factory          India  2021-09-24          2021
#
#   rating   duration                                          listed_in  \
# 0  PG-13     90 min                                      Documentaries
# 1  TV-MA  2 Seasons    International TV Shows, TV Dramas, TV Mysteries
# 2  TV-MA   1 Season  Crime TV Shows, International TV Shows, TV Act...
# 3  TV-MA   1 Season                             Docuseries, Reality TV
# 4  TV-MA  2 Seasons  International TV Shows, Romantic TV Shows, TV ...
#
#   principal_country    ages
# 0     United States   Teens
# 1      South Africa  Adults
# ...

# %%
# Convert categorical 'rating' to numeric via one-hot encoding or label encoding
movies['rating_encoded'] = movies['rating'].astype('category').cat.codes

# Correlation with rating and year
correlation_full = movies[['duration_num', 'release_year', 'rating_encoded']].corr()

# Heatmap
plt.figure(figsize=(6,4))
sns.heatmap(correlation_full, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix (Duration, Year, Rating)')
plt.show()
